# %%
import pandas as pd

dados = {
    "produto": ["Notebook", "Mouse", "Teclado", "Monitor", "Headset", "Cadeira Gamer"],
    "preco": [3500, 80, 150, 900, 250, 1200]
}

df = pd.DataFrame(dados)

media_preco = df["preco"].mean()
maior_preco = df["preco"].max()

print("Média de preços:", media_preco)
print("Produto mais caro:", maior_preco)

display(df)
# Out:
# Média de preços: 1013.3333333333334
# Produto mais caro: 3500
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>produto</th><th>preco</th></tr></thead><tbody><tr><td>Notebook</td><td>3500</td></tr><tr><td>Mouse</td><td>80</td></tr><tr><td>Teclado</td><td>150</td></tr><tr><td>Monitor</td><td>900</td></tr><tr><td>Headset</td><td>250</td></tr><tr><td>Cadeira Gamer</td><td>1200</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
